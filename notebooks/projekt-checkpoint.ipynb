# %%
import pandas as pd
hp = pd.read_csv('C:/Users/buw-ki/Desktop/Data_science/house_price.csv',index_col=0 )

# %%
hp.head(5)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 2          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 3          Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 4          Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 5          Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#    MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
hp = pd.read_csv('C:/Users/buw-ki/PycharmProjects/Python_Datascientist/AliExpress_Reviews_20000.csv' )

# %%
hp.head(5)
# Out:
#     Consumer Name Review Count Relative Time             Absolute Time  \
# 0  Brandon martin      1review   An hour ago  2025-06-17T02:51:53.000Z
# 1         Luciana     5reviews   2 hours ago  2025-06-17T02:01:33.000Z
# 2           Venom     7reviews   6 hours ago  2025-06-16T22:29:00.000Z
# 3          Caspar     3reviews   6 hours ago  2025-06-16T22:23:12.000Z
# 4      Samir Goel     2reviews   8 hours ago  2025-06-16T20:28:12.000Z
#
#    Rating                                              Title  \
# 0       1  AliExpress Sold Me a $3,000+ Defective Printer...
# 1       1         I bought a dress, but I received a blouse.
# 2       1                                         Fake items
# 3       1                                  I lost 64,78 euro
# 4       1                             Fraud company not real
#
#                                               Review Appearance Date  \
# 0  In November 2024, I placed an order for an ind...              US
# ...

# %%
hp['Review'][0]
# Out:
# 'In November 2024, I placed an order for an industrial DTF printer with a shaker add-on through the AliExpress platform. The cost of this machine was $3,065.21, and it was advertised as a turnkey solution that included all necessary components, software, and instructions. I am a small business owner and made this purchase in good faith to help grow my family-run operation. What I received instead was a non-functional, damaged, and incomplete machine that has caused significant financial loss and disruption to my business.The printer arrived over a month later than promised during checkout. When it was finally delivered, it was left in the road during snow and rain without a required signature, and without our knowledge. The box arrived visibly damaged, with broken latches, missing padding that should have protected sensitive components, and visible footprints on a sticker labeled “do not step.” Upon unboxing, it became clear the machine was not operational. The shaker component—which
# ...

# %%
hp.head(10)
# Out:
#      Consumer Name Review Count        Relative Time  \
# 0   Brandon martin      1review          An hour ago
# 1          Luciana     5reviews          2 hours ago
# 2            Venom     7reviews          6 hours ago
# 3           Caspar     3reviews          6 hours ago
# 4       Samir Goel     2reviews          8 hours ago
# 5    James Pastore      1review          9 hours ago
# 6  Martin O'Mahony     5reviews         11 hours ago
# 7      Tim Cleaver     2reviews         17 hours ago
# 8             Paul     4reviews         17 hours ago
# 9     Kimberly Tsu      1review  Updated 6 hours ago
#
#               Absolute Time  Rating  \
# 0  2025-06-17T02:51:53.000Z       1
# 1  2025-06-17T02:01:33.000Z       1
# 2  2025-06-16T22:29:00.000Z       1
# 3  2025-06-16T22:23:12.000Z       1
# 4  2025-06-16T20:28:12.000Z       1
# 5  2025-06-16T19:12:49.000Z       1
# 6  2025-06-16T17:04:07.000Z       1
# 7  2025-06-16T11:36:17.000Z       1
# 8  2025-06-16T11:36:03.000Z       5
# ...

# %%
hp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Consumer Name    19995 non-null  object
#  1   Review Count     20000 non-null  object
#  2   Relative Time    20000 non-null  object
#  3   Absolute Time    20000 non-null  object
#  4   Rating           20000 non-null  int64
#  5   Title            20000 non-null  object
#  6   Review           18631 non-null  object
#  7   Appearance Date  19995 non-null  object
#  8   Company Reply    20000 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 1.4+ MB

# %%
missing_values = hp.isnull().sum()
missing_values
# Out:
# Consumer Name         5
# Review Count          0
# Relative Time         0
# Absolute Time         0
# Rating                0
# Title                 0
# Review             1369
# Appearance Date       5
# Company Reply         0
# dtype: int64

# %%
hp['Absolute Time'] = pd.to_datetime(hp['Absolute Time'], errors='coerce')

# %%
hp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Consumer Name    19995 non-null  object
#  1   Review Count     20000 non-null  object
#  2   Relative Time    20000 non-null  object
#  3   Absolute Time    20000 non-null  datetime64[ns, UTC]
#  4   Rating           20000 non-null  int64
#  5   Title            20000 non-null  object
#  6   Review           18631 non-null  object
#  7   Appearance Date  19995 non-null  object
#  8   Company Reply    20000 non-null  object
# dtypes: datetime64[ns, UTC](1), int64(1), object(7)
# memory usage: 1.4+ MB

# %%
hp['Company Reply'][1]
# Out:
# 'Reply from AliExpress (2 hours ago): Dear Valued Customer,We deeply regret the inconvenience caused by the discrepancy in the item you received. Please rest assured that we are taking this matter very seriously and are proactively investigating the issue you reported regarding the incorrect item.We appreciate your patience as we work to resolve this matter. You can expect a detailed and thorough update to be sent to your email, and we will ensure that this thread remains up to date. Kindly keep an eye on your inbox for our communication.Your understanding and support mean a great deal to us, and we are committed to ensuring your satisfaction. Thank you for giving us the opportunity to address this issue.Warm regards,AliExpress Customer Service Team'

# %%
hp[ hp['Consumer Name'] == 'Luciana' ]
# Out:
#   Consumer Name Review Count Relative Time             Absolute Time  Rating  \
# 1       Luciana     5reviews   2 hours ago 2025-06-17 02:01:33+00:00       1
#
#                                         Title  \
# 1  I bought a dress, but I received a blouse.
#
#                                               Review Appearance Date  \
# 1  I bought a dress on AliExpress and received a ...              GB
#
#                                        Company Reply
# 1  Reply from AliExpress (2 hours ago): Dear Valu...

# %%
hp.head(10)
# Out:
#      Consumer Name Review Count        Relative Time  \
# 0   Brandon martin      1review          An hour ago
# 1          Luciana     5reviews          2 hours ago
# 2            Venom     7reviews          6 hours ago
# 3           Caspar     3reviews          6 hours ago
# 4       Samir Goel     2reviews          8 hours ago
# 5    James Pastore      1review          9 hours ago
# 6  Martin O'Mahony     5reviews         11 hours ago
# 7      Tim Cleaver     2reviews         17 hours ago
# 8             Paul     4reviews         17 hours ago
# 9     Kimberly Tsu      1review  Updated 6 hours ago
#
#               Absolute Time  Rating  \
# 0 2025-06-17 02:51:53+00:00       1
# 1 2025-06-17 02:01:33+00:00       1
# 2 2025-06-16 22:29:00+00:00       1
# 3 2025-06-16 22:23:12+00:00       1
# 4 2025-06-16 20:28:12+00:00       1
# 5 2025-06-16 19:12:49+00:00       1
# 6 2025-06-16 17:04:07+00:00       1
# 7 2025-06-16 11:36:17+00:00       1
# 8 2025-06-16 11:36:03+00:00       5
# ...

# %%
df = pd.read_csv('C:/Users/buw-ki/PycharmProjects/Python_Datascientist/AliExpress_Reviews.csv' )
df.head(10)
# Out:
#   Consumer Name Review Count        Relative Time             Absolute Time  \
# 0        miki m     2reviews        4 minutes ago  2025-06-18T14:58:40.000Z
# 1  Ian Butchart    72reviews        6 minutes ago  2025-06-18T14:56:54.000Z
# 2    Howard Lam    34reviews          An hour ago  2025-06-18T13:41:54.000Z
# 3          Guss      1review          An hour ago  2025-06-18T13:38:54.000Z
# 4         Belle      1review          2 hours ago  2025-06-18T13:01:24.000Z
# 5   Mauro Pesce     6reviews  Updated 3 hours ago  2025-06-18T12:22:09.000Z
# 6      Ed Lewis    14reviews          5 hours ago  2025-06-18T09:37:05.000Z
# 7       Mike D.     2reviews          7 hours ago  2025-06-18T08:20:40.000Z
# 8      Cosmin V     4reviews          7 hours ago  2025-06-18T08:05:49.000Z
# 9     Anonymous    18reviews          8 hours ago  2025-06-18T07:29:37.000Z
#
#    Rating                                              Title  \
# 0       1            I ordered 10pcs Disney Stitch lanyards…
# ...

# %%
df = pd.read_csv('C:/Users/buw-ki/PycharmProjects/Python_Datascientist/AliExpress_Reviews_54281.csv' )
df.head(10)
# Out:
#   Consumer Name Review Count   Relative Time             Absolute Time  \
# 0   Mauro Pesce     6reviews  16 minutes ago  2025-06-18T11:51:22.000Z
# 1      Ed Lewis    14reviews     3 hours ago  2025-06-18T09:37:05.000Z
# 2       Mike D.     2reviews     4 hours ago  2025-06-18T08:20:40.000Z
# 3      Cosmin V     4reviews     4 hours ago  2025-06-18T08:05:49.000Z
# 4     Anonymous    18reviews     5 hours ago  2025-06-18T07:29:37.000Z
# 5       Moniker      1review     5 hours ago  2025-06-18T07:12:37.000Z
# 6     Christian      1review    13 hours ago  2025-06-17T23:29:32.000Z
# 7    Samir Goel     3reviews    15 hours ago  2025-06-17T20:39:27.000Z
# 8       oussama    19reviews    18 hours ago  2025-06-17T17:53:21.000Z
# 9       Chris D     2reviews    19 hours ago  2025-06-17T17:11:53.000Z
#
#    Rating                                              Title  \
# 0       1              I ordered twice and both times I had…
# 1       1  Worst customer service team on the face of the...
# ...

# %%
df[ df['Consumer Name'] == 'oussama' ]
# Out:
#   Consumer Name Review Count Relative Time             Absolute Time  Rating  \
# 8       oussama    19reviews  18 hours ago  2025-06-17T17:53:21.000Z       5
#
#                                                Title  \
# 8  Outstanding Customer Support - Refund Issue Fu...
#
#                                               Review Review Country  \
# 8  I recently had an issue involving a refund fro...             TN
#
#   Experience date                                      Company Reply
# 8   June 17, 2025  Reply from AliExpress (9 hours ago): oussama,W...

# %%
df[ df['Consumer Name'] == 'Samir Goel' ]
# Out:
#   Consumer Name Review Count Relative Time             Absolute Time  Rating  \
# 7    Samir Goel     3reviews  15 hours ago  2025-06-17T20:39:27.000Z       1
#
#                                     Title  \
# 7  Aliexpress is causing a huge headache…
#
#                                               Review Review Country  \
# 7  Aliexpress is causing a huge headache on a pro...             CA
#
#   Experience date                                      Company Reply
# 7   June 17, 2025  Reply from AliExpress (9 hours ago): Dear Cust...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54281 entries, 0 to 54280
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Consumer Name    54275 non-null  object
#  1   Review Count     54281 non-null  object
#  2   Relative Time    54281 non-null  object
#  3   Absolute Time    54281 non-null  object
#  4   Rating           54281 non-null  int64
#  5   Title            54281 non-null  object
#  6   Review           44369 non-null  object
#  7   Review Country   54267 non-null  object
#  8   Experience date  54281 non-null  object
#  9   Company Reply    54281 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 4.1+ MB

# %%
df.shape
# Out:
# (54281, 10)

# %%
df['Company Reply'][1000]
# Out:
# "Reply from AliExpress (Updated Apr 25, 2025): Dear Customer,Due to the lack of completed request information form, we regret to inform you that we are unable to process your case due to insufficient information. Please accept our deepest apologies for any inconvenience you've faced. If you need further assistance or have any additional questions, please don't hesitate to consult our Help Center at AliExpress.https://helpcenter.aliexpress.com/s/BuyerHelpThank you for your understanding and cooperation.Best regards,AliExpress Customer Service Team"

# %%
tf = pd.read_csv('C:/Users/buw-ki/PycharmProjects/Python_Datascientist/AliExpress_Reviews_test.csv' )
tf.head(10)
# Out:
#                      UserId                   UserName  ReviewCount  \
# 0  67d900467062e8bdc2d6ea6a                 Samir Goel            4
# 1  6494d2c413b25f0012e5c996              Peter Stapper            4
# 2  5ffc84476588cd00199c791b  Lykke og Jens Erik Elkrog           13
# 3  5bca418d4de5666d34b6d69a             neil griffiths            4
# 4  685426662f247803b7240587               Tristan Zhou            1
# 5  68540fcd2824b57ade185674                  John Jose            1
# 6  6854079c4e662d42d9471b14               Phoenix Boto            1
# 7  682855bab83f2cbf6181cbad                    Chris D            3
# 8  57680ecb0000ff000a2ae646                   LEZMAR63           11
# 9  60a2894217db59001be8d1a7                      Marco            8
#
#     Relative Time                ReviewDate  ReviewRating  \
# 0  28 minutes ago  2025-06-19T22:02:17.000Z             1
# 1     2 hours ago  2025-06-19T20:30:10.000Z             1
# ...

# %%
tf = pd.read_csv('C:/Users/buw-ki/PycharmProjects/Python_Datascientist/AliExpress_Reviews_20_06_2025.csv' )
tf.tail(100)
# Out:
#                          UserId           UserName  ReviewCount  \
# 53900  5395c2bd00006400017845e9              Heidi            1
# 53901  53955e170000640001783220      Peter McGrath            1
# 53902  5395437a0000640001782f50               Ella            2
# 53903  539491f60000640001781eae  Banafsheh Tehrani            1
# 53904  5392b09b000064000177eb1e              nancy            1
# ...                         ...                ...          ...
# 53995  5351100400006400016ee1ec           Jacob S.            1
# 53996  5350e6bd00006400016edc4a        Evhen Bilyi            1
# 53997  53505cae00006400016ed304    Sara Mata Nuñez            8
# 53998  53500ac100006400016ec74e                sam            1
# 53999  534fdaf600006400016ebeb2         Lavnia Rao            1
#
#              Relative Time                ReviewDate  ReviewRating  \
# 53900          Jun 9, 2014  2014-06-09T14:57:22.000Z             1
# ...

# %%
tf['ReplyTime'].isna().sum()
# Out:
# np.int64(43315)

# %%
tf.shape
# Out:
# (54000, 12)

# %%
tf[tf['UserName'] == 'Samir Goel']
# Out:
#                      UserId    UserName  ReviewCount   Relative Time  \
# 0  67d900467062e8bdc2d6ea6a  Samir Goel            4  28 minutes ago
#
#                  ReviewDate  ReviewRating  \
# 0  2025-06-19T22:02:17.000Z             1
#
#                               ReviewTitle  \
# 0  AliExpress Continues To Be A Headache…
#
#                                           ReviewText ReviewCountry  \
# 0  AliExpress Continues To Be A Headache To Deal ...            CA
#
#   ReviewExperienceDate ReplyText ReplyTime
# 0        June 18, 2025  No reply       NaN

# %%
tf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54000 entries, 0 to 53999
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   UserId                54000 non-null  object
#  1   UserName              53995 non-null  object
#  2   ReviewCount           54000 non-null  int64
#  3   Relative Time         54000 non-null  object
#  4   ReviewDate            54000 non-null  object
#  5   ReviewRating          54000 non-null  int64
#  6   ReviewTitle           54000 non-null  object
#  7   ReviewText            44090 non-null  object
#  8   ReviewCountry         53986 non-null  object
#  9   ReviewExperienceDate  54000 non-null  object
#  10  ReplyText             54000 non-null  object
#  11  ReplyTime             10685 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 4.9+ MB

# %%
tf_test = pd.read_csv('C:/Users/buw-ki/PycharmProjects/Python_Datascientist/AliExpress_Reviews_400_test.csv' )
tf_test.head(30)
# Out:
#                       UserId                   UserName  ReviewCount  \
# 0   633ee58a6c0e080012e0a996            Darius Colompar            4
# 1   648d82bc0fb7ec0012026e79                    Mr. LAM            5
# 2   5b5981664de5666d34fed381                       Igor           19
# 3   6854d97c8a537547eb740c6e                        j c            1
# 4   605f83cca0751a0019ecfcff            Deborah Mathieu            3
# 5   65e8340ae05d3f0013293e77            George Murgeanu            7
# 6   66ab548ae52f7248cf895edb              Esa Butt Butt            5
# 7   67d900467062e8bdc2d6ea6a                 Samir Goel            4
# 8   6494d2c413b25f0012e5c996              Peter Stapper            4
# 9   5ffc84476588cd00199c791b  Lykke og Jens Erik Elkrog           13
# 10  5bca418d4de5666d34b6d69a             neil griffiths            4
# 11  685426662f247803b7240587               Tristan Zhou            1
# 12  6854079c4e662d42d9471b14               Phoenix Boto            1
# ...

# %%
tf_test['ReviewTitle'][1]
# Out:
# '🔴 ALIEXPRESS KEPT BOTH MY MONEY AND MY RETURNED ITEM — OUTRAGEOUS CONDUCT!   🔴'

# %%
temu_df = pd.read_csv('C:/Users/buw-ki/PycharmProjects/Python_Datascientist/Temu_Reviews_15000_.csv' )

# %%
temu_df.head(10)
# Out:
#                      UserId         UserName  ReviewCount   Relative Time  \
# 0  679a1aab5ddf67bc19532ced   Anna Magnowska            3   6 minutes ago
# 1  54889c1e00006400019c90db    Anson Bentley            8  38 minutes ago
# 2  628fd04dfe22a000129825d8          Shelley            5     An hour ago
# 3  56f144ac0000ff000a10d59d        John Bose           10     3 hours ago
# 4  67b6ec9dd7c729460420abc5  Arthur Precious            3     4 hours ago
# 5  685afe2d8a5375c6da7a2f97     Brian Lupton            1     4 hours ago
# 6  685af6aa8a5375281d7a24fc  Richie Dorllarz            1     5 hours ago
# 7  512aa3ae000064000131f860   BrianD Erhardt            5     5 hours ago
# 8  6521d940a06149001228ca68     Kacem belhaj            1     5 hours ago
# 9  5754b1f20000ff000a267e52               SG           30     6 hours ago
#
#                  ReviewDate  ReviewRating  \
# 0  2025-06-25T01:37:17.000Z           1.0
# 1  2025-06-25T01:05:00.000Z           5.0
# ...

# %%
Aliexpress_df = pd.read_csv('C:/Users/buw-ki/PycharmProjects/Python_Datascientist/AliExpress_Reviews_54280.csv' )

# %%
Wish_df = pd.read_csv('C:/Users/buw-ki/PycharmProjects/Python_Datascientist/Wish_Reviews_100000_.csv' )

# %%
Wish_df.isna().sum()
# Out:
# UserId                      0
# UserName                    6
# ReviewCount                 0
# Relative Time               0
# ReviewDate                  0
# ReviewRating                0
# ReviewTitle                 7
# ReviewText              17438
# ReviewCountry               6
# ReviewExperienceDate        0
# ReplyText                   0
# ReplyTime               83427
# dtype: int64
